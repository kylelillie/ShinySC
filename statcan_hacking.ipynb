# %%
def get_cube_metadata(product_id, endpoint=None, timeout=30):
    """
    Retrieves metadata for a cube (table) from Statistics Canada WDS.

    Args:
        product_id (int or str): The product ID (PID) of the cube (e.g., 35100003).
        endpoint (str): Optional custom endpoint URL (defaults to the documented one).
        timeout (float): Timeout in seconds for the HTTP request.

    Returns:
        dict: JSON response object converted to Python dict.
    """
    if endpoint is None:
        endpoint = "https://www150.statcan.gc.ca/t1/wds/rest/getCubeMetadata"

    # Prepare payload as list of dicts, per documentation example. :contentReference[oaicite:2]{index=2}
    payload = [
        {
            "productId": str(product_id)
        }
    ]

    headers = {
        "Content-Type": "application/json"
    }

    try:
        response = requests.post(endpoint, headers=headers, json=payload, timeout=timeout)
        response.raise_for_status()
        data = response.json()

        # Check for status
        if data[0]["status"] != "SUCCESS":
            raise RuntimeError(f"Request returned non-SUCCESS status: {data}")
        
        return data[0]['object']
    
    except requests.RequestException as e:
        raise RuntimeError(f"HTTP request failed: {e}") from e
    
    except json.JSONDecodeError as e:
        raise RuntimeError(f"Failed to parse JSON response: {e}") from e

# %%
import requests
import pandas as pd
from io import BytesIO
import urllib.parse
import json
from datetime import datetime, timedelta
from IPython.core.display import display, HTML


url = "https://www150.statcan.gc.ca/t1/wds/rest/getAllCubesList"
resp = requests.get(url)
tables = resp.json()

card_css = "border:1px solid black;margin:10px;padding:10px;background:white;max-width:200px;border-radius:3px;color:black;"
n = 2

count = 0

df = pd.DataFrame(tables)
df = df[[x for x in df.columns if x if 'Fr' not in x]]
df = df[df['archived'] == '2']

def get_table(id,n,enc,region_type=''):

    url = f'https://www150.statcan.gc.ca/t1/tbl1/en/dtl!downloadDbLoadingData-nonTraduit.action?pid={id}01&latestN={n}&startDate=&endDate=&csvLocale=en&selectedMembers={enc}&checkedLevels=0D1%2C0D1%2C0D2'
    print(url)
    df = pd.read_csv(url)
    if region_type != '':
        df = df[df.DGUID.str[6:9] == region_type]

    display(df)

def parse_dim(x):

    tmp = {}
    sel = []

    for i in x:

        tmp[i['dimensionNameEn']] = i['hasUOM']
        sel.append([1])
    
    return tmp,sel

archived_tables = df[df['archived'] == '1']
active_tables = df[df['archived'] == '2']

for p in tables:

    id = p['productId']
    endDate = datetime.fromisoformat(p['cubeEndDate'].replace("Z", "+00:00")).replace(tzinfo=None)

    if p['archived'] == '2':

        metadata = get_cube_metadata(id)
        num_dimensions = len(metadata['dimension'])
        data = metadata['dimension']

        tablename = p['cubeTitleEn']
        dim = p['dimensions']
        dim,selected = parse_dim(dim)

        raw = json.dumps(selected, separators=(',',':'))
        enc = urllib.parse.quote(raw)

        num_param = len(data)

        attributes = {}
        attributes['Table Name'] = tablename

        for i in range(0,num_param):

            sub_size = len(data[i]['member'])
            top_name = data[i]['dimensionNameEn']

            for j in range(0,sub_size):
                
                #print(data[i]['member'][j])

                name = data[i]['member'][j]['memberNameEn']
                classification = data[i]['member'][j]['classificationCode']

                if top_name in attributes:
                    attributes[top_name].append(name)
                else:
                    attributes[top_name] = [name]

        print(id,' - ',tablename,'\n',attributes)
        #get_table(id=id,n=n,enc=enc)#region_type='503')
        
        count += 1

        if count > 5:
            break
# Out:
# C:\Users\kylel\AppData\Local\Temp\ipykernel_19944\2154275600.py:7: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# 10100002  -  Central government debt
#  {'Table Name': 'Central government debt', 'Geography': ['Canada'], 'Central government debt': ['A. Federal debt (accumulated deficit), (B - E)', 'B. Net debt, (C - D)', 'C. Liabilities, gross debt', 'Accounts payable and accrued liabilities', 'Interest-bearing debt', 'Unmatured debt', 'Market debt payable in Canadian currency', 'Marketable bonds payable in Canadian currency', 'Treasury bills', 'Retail debt', 'Other market debt payable in Canadian currency', 'Market debt payable in foreign currencies', 'Marketable bonds payable in foreign currencies', 'Medium-term notes', 'Canada bills', 'Cross currency swap revaluation', 'Unamortized discounts and premiums on market debt', 'Obligations related to capital leases and other unmatured debt', 'Pensions and other accounts', 'Foreign exchange accounts liabilities', 'Derivatives', 'D. Financial assets', 'Cash and accounts receivable', 'Foreign exchange accounts', 'Foreign exchange accounts assets', 'Derivatives', 'Loans, investments and advances', 'Public sector pension assets', 'E. Non-financial assets', 'Market debt', 'a) Short-term', 'b) Long-term', 'Total Outstanding Guarantees']}
# 10100003  -  Government of Canada debt securities: Gross new issues, retirements and net new issues, par value, Bank of Canada
#  {'Table Name': 'Government of Canada debt securities: Gross new issues, retirements and net new issues, par value, Bank of Canada', 'Geography': ['Canada and Abroad', 'Canada', 'Abroad', 'United States', 'Other Countries'], 'Type of issues': ['Gross new issues', 'Retirements', 'Net new issues'], 'Issuers': ['Government of Canada Treasury Bills and Canada bills issued in U.S. dollars', 'Total Treasury Bills', '91-day Treasury Bills', 'Government of Canada direct and guaranteed bonds', 'Of which: Retail debt', 'Of which: Canada Savings Bonds', 'Total provincial and municipal short-term paper, including Canada Bills issued in U.S. dollars', 'Provincial direct and guaranteed bonds', 'Canada Pension Plan', 'Other bonds', 'Municipal direct and guaranteed bonds', 'Total commercial paper', "Canadian dollar bankers' acceptances", 'Term securitizations: National Housing Act (NHA) mortgage-backed securities', 'Term securitizations: other asset-backed securities', 'Corporate bonds', 'Financial', 'Non-financial', 'Preferred stocks', 'Financial', 'Non-financial', 'Common stocks', 'Financial', 'Non-financial', 'Trust units', 'Financial', 'Non-financial', 'Other institutions and foreign debtors']}
# 10100004  -  Chartered banks, total claims and liabilities booked worldwide vis-à-vis non-residents, Bank of Canada
#  {'Table Name': 'Chartered banks, total claims and liabilities booked worldwide vis-à-vis non-residents, Bank of Canada', 'Geography': ['Canada'], 'Claims and deposits': ['Claims', 'Deposits'], 'Type of non-resident': ['Total, non-residents', 'Non-residents of which: banks', 'Non-residents of which: non-local'], 'Country of non-resident': ['Total, booked', 'United States', 'Austria', 'Belgium', 'France', 'Germany', 'Italy', 'Netherlands', 'Spain', 'Sweden', 'Switzerland', 'United Kingdom', 'Other Europe', 'Poland', 'Russia', 'Other Central Europe and Central Asia', 'Australia', "People's Republic Of China", 'India', 'Japan', 'Republic Of South Korea', 'Malaysia', 'New Zealand', 'Philippines', 'Taiwan', 'Thailand', 'Other East Asia and the Pacific', 'Argentina', 'Bolivia', 'Brazil', 'Chile', 'Mexico', 'Peru', 'Trinidad and Tobago', 'Venezuela', 'Other Latin America and Caribbean', 'Algeria', 'Kuwait', 'Saudi Arabia', 'Other North Africa and Middle East', 'Republic Of South Africa', 'Other Sub-Saharan Africa', 'Unallocated', 'Bahamas', 'Barbados', 'Bermuda', 'Cayman Islands', 'Hong Kong', 'Panama', 'Singapore', 'Other off-shore banking centers', 'Foreign currency on Canadian residents', 'Total Europe', 'Total Central Europe and Central Asia', 'Total East Asia and the Pacific', 'Total Latin America and Caribbean', 'Total North Africa and Middle East', 'Total Sub-Saharan Africa', 'Total off-shore banking centers']}
# 10100005  -  Canadian Classification of Functions of Government (CCOFOG) by consolidated government component
#  {'Table Name': 'Canadian Classification of Functions of Government (CCOFOG) by consolidated government component', 'Geography': ['Canada', 'Newfoundland and Labrador', 'Prince Edward Island', 'Nova Scotia', 'New Brunswick', 'Quebec', 'Ontario', 'Manitoba', 'Saskatchewan', 'Alberta', 'British Columbia', 'Yukon', 'Northwest Territories', 'Nunavut'], 'Public sector components': ['Consolidated Canadian general government', 'Consolidated provincial-territorial and local governments'], 'Canadian Classification of Functions of Government (CCOFOG)': ['General public services', 'Executive and legislative organs, financial and fiscal affairs and external affairs', 'Foreign economic aid', 'General services', 'Basic Research', 'Public debt transactions', 'General public services not elsewhere classified', 'Defence', 'Military defence', 'Civil defence', 'Foreign military aid', 'Defence not elsewhere classified', 'Public order and safety', 'Police services', 'Fire protection services', 'Law courts', 'Prisons', 'Public order and safety not elsewhere classified', 'Economic affairs', 'General economic, commercial, and labor affairs', 'Agriculture, forestry, fishing, and hunting', 'Fuel and energy', 'Mining, manufacturing, and construction', 'Transport', 'Economic affairs not elsewhere classified', 'Environmental protection', 'Waste management', 'Waste water management', 'Pollution abatement', 'Protection of biodiversity and landscape', 'Environmental protection not elsewhere classified', 'Housing and community amenities', 'Housing and community development', 'Water supply', 'Street lighting', 'Housing and community amenities not elsewhere classified', 'Health', 'Medical products, appliances, and equipment', 'Outpatient services', 'Hospital services', 'Public health services', 'Health not elsewhere classified', 'Recreation, culture and religion', 'Recreational and sporting services', 'Cultural services', 'Broadcasting and publishing services', 'Recreation, culture, and religion not elsewhere classified', 'Education', 'Primary and secondary education', 'College education', 'University education', 'Education not elsewhere classified', 'Social protection', 'Sickness and disability', 'Old age', 'Family and children', 'Unemployment', 'Housing', 'Social exclusion', 'Social protection not elsewhere classified']}
# 10100006  -  Funds advanced, outstanding balances, and interest rates for new and existing lending, Bank of Canada
#  {'Table Name': 'Funds advanced, outstanding balances, and interest rates for new and existing lending, Bank of Canada', 'Geography': ['Canada'], 'Components': ['Total, funds advanced, residential mortgages, insured', 'Variable rate, funds advanced, residential mortgages, insured', 'Fixed rate, funds advanced, residential mortgages, insured, less than 1  year', 'Fixed rate, funds advanced, residential mortgages, insured, from 1  to less than 3 years', 'Fixed rate, funds advanced, residential mortgages, insured, from 3 to less than 5 years', 'Fixed rate, funds advanced, residential mortgages, insured, 5 years and more', 'Total, funds advanced, residential mortgages, uninsured', 'Variable rate, funds advanced, residential mortgages, uninsured', 'Fixed rate, funds advanced, residential mortgages, uninsured, less than 1 year', 'Fixed rate, funds advanced, residential mortgages, uninsured, from 1 to less than 3 years', 'Fixed rate, funds advanced, residential mortgages, uninsured, from 3 to less than 5 years', 'Fixed rate, funds advanced, residential mortgages, uninsured, 5 years and more', 'Total, outstanding balances, residential mortgages, insured', 'Variable rate, outstanding balances, residential mortgages, insured', 'Fixed rate, outstanding balances, residential mortgages, insured, less than 1 year', 'Fixed rate, outstanding balances, residential mortgages, insured, from 1 to less than 3 years', 'Fixed rate, outstanding balances, residential mortgages, insured, from 3 to less than 5 years', 'Fixed rate, outstanding balances, residential mortgages, insured, 5 years and over', 'Total, outstanding balances, residential mortgages, uninsured', 'Variable rate, outstanding balances, residential mortgages, uninsured', 'Fixed rate, outstanding balances, residential mortgages, uninsured, less than 1 year', 'Fixed rate, outstanding balances, residential mortgages, uninsured, from 1 to less than 3 years', 'Fixed rate, outstanding balances, residential mortgages, uninsured, from 3 to less than 5 years', 'Fixed rate, outstanding balances, residential mortgages, uninsured, 5 years and more', 'Total, funds advanced, variable rate mortgages', 'Funds advanced, closed non-convertible variable rate mortgages', 'Funds advanced, closed convertible variable rate mortgages', 'Funds advanced, open variable rate mortgages', 'Total, funds advanced for non-mortgage loans, consumer credit', 'Funds advanced for non-mortgage loans, consumer credit, personal loan plans', 'Funds advanced for non-mortgage loans, personal loan plans, consumer credit, Of which are auto loans', 'Funds advanced for non-mortgage loans, consumer credit, personal lines of credit, secured', 'Funds advanced for non-mortgage loans, consumer credit, personal lines of credit, unsecured', 'Funds advanced for non-mortgage loans, consumer credit, other personal', 'Total, outstanding balances for non-mortgage loans, consumer credit', 'Outstanding balances for non-mortgage loans, consumer credit, personal loan plans', 'Outstanding balances for non-mortgage loans, consumer credit, personal loan plans, Of which are auto loans', 'Outstanding balances for non-mortgage loans, consumer credit, credit card loans', 'Outstanding balances for non-mortgage loans, consumer credit, personal lines of credit, secured', 'Outstanding balances for non-mortgage loans, consumer credit, personal lines of credit, unsecured', 'Outstanding balances for non-mortgage loans, consumer credit, other personal', 'Total, funds advanced, business loans', 'Funds advanced, business loans, to regulated non-bank financial institutions', 'Funds advanced, business loans, lease receivables', 'Funds advanced, business loans, loans to individuals and others for business purposes', 'Funds advanced, business loans, non-residential mortgages', 'Total, outstanding balances, business loans', 'Outstanding balances, business loans, to regulated non-bank financial institutions', 'Outstanding balances, business loans, lease receivables', 'Out ...
# 10100010  -  Sales of alcoholic beverages types by liquor authorities and other retail outlets, by value, volume, and absolute volume
#  {'Table Name': 'Sales of alcoholic beverages types by liquor authorities and other retail outlets, by value, volume, and absolute volume', 'Geography': ['Canada', 'Newfoundland and Labrador', 'Prince Edward Island', 'Nova Scotia', 'New Brunswick', 'Quebec', 'Ontario', 'Manitoba', 'Saskatchewan', 'Alberta', 'British Columbia', 'Yukon', 'Northwest Territories', 'Nunavut'], 'Type of sales': ['Total sales', 'Total per capita sales'], 'Type of beverage': ['Total alcoholic beverages', 'Spirits', 'Wines', 'Beer', 'Ciders, Coolers, and Other Refreshment Beverages'], 'Value, volume and absolute volume': ['Value for total sales', 'Volume for total sales', 'Absolute volume for total sales', 'Value for total per capita sales', 'Volume for total per capita sales', 'Absolute volume for total per capita sales']}
