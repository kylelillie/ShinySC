# %%
import requests
import pandas as pd
import urllib.parse
import json
from datetime import datetime
from IPython.core.display import display, HTML
from pprint import pprint

class ssc:

    def __init__(self,id=''):

        self.id = id
        self.shinysc = None

    #Be able to get data for a specific table []
    #Be able to get data for all tables in a specific category []
    #Be able to get data for all tables []

    def get_metadata(id, endpoint=None, timeout=30, lang='all'):
        """
        Retrieves metadata for a cube (table) from Statistics Canada WDS.

        Args:
            id (int or str): The product ID (PID) of the cube (e.g., 35100003).
            endpoint (str): Optional custom endpoint URL (defaults to the documented one).
            timeout (float): Timeout in seconds for the HTTP request.
            lang (str): Language preference for the metadata ('en', 'fr', or 'all').

        Returns:
            dict: JSON response object converted to Python dict.
        """
        if endpoint is None:
            endpoint = "https://www150.statcan.gc.ca/t1/wds/rest/getCubeMetadata"

        # Prepare payload as list of dicts, per documentation example. :contentReference[oaicite:2]{index=2}
        payload = [
            {
                "productId": str(id)
            }
        ]

        headers = {
            "Content-Type": "application/json"
        }

        def _remove_lang(obj,language):
            
            if isinstance(obj, dict):
                
                obj = {k: _remove_lang(v,language) for k, v in obj.items() if not k.endswith(language)}

                for k in obj.keys():
                    if isinstance(obj[k],list):
                        if len(obj[k]) > 0:
                            if isinstance(obj[k][0],dict):
                                print(k)
                                obj[k] = [_remove_lang(i,language) for i in obj[k]]
                return obj
            
            else:
                return obj

        try:
            response = requests.post(endpoint, headers=headers, json=payload, timeout=timeout)
            response.raise_for_status()
            data = response.json()

            # Check for status
            if data[0]["status"] != "SUCCESS":
                raise RuntimeError(f"Request returned non-SUCCESS status: {data}")
            
            if lang == 'en':
                return _remove_lang(data[0]['object'],'Fr')
            
            elif lang == 'fr':
                return _remove_lang(data[0]['object'],'En')
            
            else:
                return data[0]['object']
        
        except requests.RequestException as e:
            raise RuntimeError(f"HTTP request failed: {e}") from e
        
        except json.JSONDecodeError as e:
            raise RuntimeError(f"Failed to parse JSON response: {e}") from e

    def get_table(id,n,enc,region_type=''):

        url = f'https://www150.statcan.gc.ca/t1/tbl1/en/dtl!downloadDbLoadingData-nonTraduit.action?pid={id}01&latestN={n}&startDate=&endDate=&csvLocale=en&selectedMembers={enc}&checkedLevels=0D1%2C0D1%2C0D2'
        print(url)
        df = pd.read_csv(url)
        if region_type != '':
            df = df[df.DGUID.str[6:9] == region_type]

        display(df)

    def parse_dim(x):

        tmp = {}
        sel = []

        for i in x:

            tmp[i['dimensionNameEn']] = i['hasUOM']
            sel.append([1])
        
        return tmp,sel

    def list_tables():

        url = "https://www150.statcan.gc.ca/t1/wds/rest/getAllCubesList"
        resp = requests.get(url)
        tables = resp.json()

        df = pd.DataFrame(tables)
        df = df[[x for x in df.columns if x if 'Fr' not in x]]
        df = df[df['archived'] == '2']

        archived_tables = df[df['archived'] == '1']
        active_tables = df[df['archived'] == '2']

        card_css = "border:1px solid black;margin:10px;padding:10px;background:white;max-width:200px;border-radius:3px;color:black;"
        n = 2

        count = 0

        for p in tables:

            id = p['productId']
            endDate = datetime.fromisoformat(p['cubeEndDate'].replace("Z", "+00:00")).replace(tzinfo=None)

            if p['archived'] == '2':

                metadata = get_metadata(id)
                num_dimensions = len(metadata['dimension'])
                data = metadata['dimension']

                tablename = p['cubeTitleEn']
                dim = p['dimensions']
                dim,selected = parse_dim(dim)

                raw = json.dumps(selected, separators=(',',':'))
                enc = urllib.parse.quote(raw)

                num_param = len(data)

                attributes = {}
                attributes['Table Name'] = tablename

                for i in range(0,num_param):

                    sub_size = len(data[i]['member'])
                    top_name = data[i]['dimensionNameEn']

                    for j in range(0,sub_size):
                        
                        #print(data[i]['member'][j])

                        name = data[i]['member'][j]['memberNameEn']
                        classification = data[i]['member'][j]['classificationCode']

                        if top_name in attributes:
                            attributes[top_name].append(name)
                        else:
                            attributes[top_name] = [name]

                print(id,' - ',tablename,'\n',attributes)
                #get_table(id=id,n=n,enc=enc)#region_type='503')
                
                count += 1

                if count > 5:
                    break
                    

meta = ssc.get_metadata(id=35100003,lang='en')
pprint(meta)
# Out:
# C:\Users\kylel\AppData\Local\Temp\ipykernel_9088\3598400966.py:6: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# dimension
# member
# member
# footnote
# {'archiveStatusCode': '2',
#  'archiveStatusFr': 'ACTIF - un cube qui est disponible au public et qui est '
#                     'toujours mise a jour',
#  'cansimId': '251-0008',
#  'correction': [],
#  'correctionFootnote': [],
#  'cubeEndDate': '2023-01-01',
#  'cubeStartDate': '1997-01-01',
#  'cubeTitleFr': 'Comptes moyens des adolescents dans les services '
#                 'correctionnels provinciaux et territoriaux',
#  'dimension': [{'dimensionNameFr': 'Géographie',
#                 'dimensionPositionId': 1,
#                 'hasUom': False,
#                 'member': [{'classificationCode': '11124',
#                             'classificationTypeCode': '1',
#                             'geoLevel': 0,
#                             'memberId': 15,
#                             'memberNameFr': 'Provinces et territoires',
#                             'memberUomCode': None,
#                             'parentMemberId': None,
#                             'terminated': 0,
#                             'vintage': 2021},
#                            {'classificationCode': '10',
#                             'classificationTypeCode': '1',
#                             'geoLevel': 2,
#                             'memberId': 1,
#                             'memberNameFr': 'Terre-Neuve-et-Labrador',
#                             'memberUomCode': None,
#                             'parentMemberId': 15,
#                             'terminated': 0,
#                             'vintage': 2021},
#                            {'classificationCode': '11',
#                             'classificationTypeCode': '1',
#                             'geoLevel': 2,
#                             'memberId': 2,
#                             'memberNameFr': 'Île-du-Prince-Édouard',
#                             'memberUomCode': None,
#                             'parentMemberId': 15,
#                             'terminated': 0,
#                             'vintage': 2021},
#                            {'classificationCode': '12',
#                             'classificationTypeCode': '1',
#                             'geoLevel': 2,
#                             'memberId': 3,
#                             'memberNameFr': 'Nouvelle-Écosse',
#                             'memberUomCode': None,
#                             'parentMemberId': 15,
#                             'terminated': 0,
#                             'vintage': 2021},
#                            {'classificationCode': '13',
#                             'classificationTypeCode': '1',
#                             'geoLevel': 2,
#                             'memberId': 4,
#                             'memberNameFr': 'Nouveau-Brunswick',
#                             'memberUomCode': None,
#                             'parentMemberId': 15,
#                             'terminated': 0,
#                             'vintage': 2021},
#                            {'classificationCode': '24',
#                             'classificationTypeCode': '1',
#                             'geoLevel': 2,
#                             'memberId': 5,
#                             'memberNameFr': 'Québec',
#                             'memberUomCode': None,
#                             'parentMemberId': 15,
#                             'terminated': 0,
#                             'vintage': 2021},
#                            {'classificationCode': '35',
#                             'classificationTypeCode': '1',
#                             'geoLevel': 2,
#                             'memberId': 6,
#                             'memberNameFr': 'Ontario',
#                             'memberUomCode': None,
#                             'parentMemberId': 15,
#                             'terminated': 0,
#                             'vintage': 2021},
#                            {'classificationCode': '46',
#                             'classificationTypeCode': '1',
#                             'geoLevel': 2,
#                             'memberId': 7,
#                             'memberNameFr': 'Manitoba',
#                             'memberUomCode': None,
#                             'parentMemberId': 15,
#                             'terminated': 0,
#                             'vintage': 2021},
#                            {'classificationCode': '47',
#                             'classificationTypeCode': '1',
#                             'geoLevel': 2,
#                             'memberId': 8,
#                             'memberNameFr': 'Saskatchewan',
#                             'memberUomCode': None,
#                             'parentMemberId': 15,
#                             'terminated': 0,
#                             'vintage': 2021},
#                            {'classificationCode': '48',
#                             'classificationTypeCode': '1',
#                             'geoLevel': 2,
#                             'memberId': 9,
#                             'memberNameFr': 'Alberta',
#                             'memberUomCode': None,
#                             'parentMemberId': 15,
#                             'terminated': 0,
#                             'vintage': 2021},
#                            {'classificationCode': '59',
#                             'classificationTypeCode': '1',
#                             'geoLevel': 2,
#                             'memberId': 10,
#                             'memberNameFr': 'Colombie-Britannique',
#                             'memberUomCode': None,
#                             'parentMemberId': 15,
#                             'terminated': 0,
#                             'vintage': 2021},
#                            {'classificationCode': '60',
#                             'classificationTypeCode': '1',
#                             'geoLevel': 2,
#                             'memberId': 11,
#                             'memberNameFr': 'Yukon',
#                             'memberUomCode': None,
#                             'parentMemberId': 15,
#                             'terminated': 0,
#                             'vintage': 2021},
#                            {'classificationCode': None,
#                             'classificationTypeCode': None,
#                             'geoLevel': None,
#                             'memberId': 12,
#                             'memberNameFr': 'Territoires du Nord-Ouest '
#                                             'incluant Nunavut',
#                             'memberUomCode': None,
#                             'parentMemberId': 15,
#                             'terminated': 1,
#                             'vintage': None},
#                            {'classificationCode': '61',
#                             'classificationTypeCode': '1',
#                             'geoLevel': 2,
#                             'memberId': 13,
#                             'memberNameFr': 'Territoires du Nord-Ouest',
#                             'memberUomCode': None,
#                             'parentMemberId': 15,
#                             'terminated': 0,
#                             'vintage': 2021},
#                            {'classificationCode': '62',
#                             'classificationTypeCode': '1',
#                             'geoLevel': 2,
#                             'memberId': 14,
#                             'memberNameFr': 'Nunavut',
#                             'memberUomCode': None,
#                             'parentMemberId': 15,
#                             'terminated': 0,
#                             'vintage': 2021}]},
#                {'dimensionNameFr': 'Surveillance dans un établissement de '
#                                    'détention et dans la collectivité',
#                 'dimensionPositionId': 2,
#                 'hasUom': True,
#                 'member': [{'classificationCode': None,
#                             'classificationTypeCode': None,
#                             'geoLevel': None,
#                             'memberId': 1,
#                             'memberNameFr': 'Compte réel total des détenus',
#                             'memberUomCode': 249,
#                             'parentMemberId': None,
#                             'terminated': 0,
#                             'vintage': None},
#                            {'classificationCode': None,
#                             'classificationTypeCode': None,
#                             'geoLevel': None,
#                             'memberId': 2,
#                             'memberNameFr': 'Total de la détention après '
#                                             'condamnation, compte réel des '
#                                             'détenus',
#                             'memberUomCode': 249,
#                             'parentMemberId': 1,
#                             'terminated': 0,
#                             'vintage': None},
#                            {'classificationCode': None,
#                             'classificationTypeCode': None,
#                             'geoLevel': None,
#                             'memberId': 3,
#                             'memberNameFr': 'Détention après condamnation, '
#                                             'garde en milieu fermé, compte '
#                                             'réel',
#                             'memberUomCode': 249,
#                             'parentMemberId': 2,
#                             'terminated': 0,
#                             'vintage': None},
#                            {'classificationCode': None,
#                             'classificationTypeCode': None,
#                             'geoLevel': None,
#                             'memberId': 4,
#                             'memberNameFr': 'Détention après condamnation, '
#                                             'garde en milieu ouvert, compte '
#                                             'réel',
#                             'memberUomCode': 249,
#                             'parentMemberId': 2,
#                             'terminated': 0,
#                             'vintage': None},
#                            {'classificationCode': None,
#                             'classificationTypeCode': None,
#                             'geoLevel': None,
#                             'memberId': 5,
#                             'memberNameFr': 'Détention avant le procès ou '
#                                             'autre type de détention '
#                                             'temporaire, compte réel',
#                             'memberUomCode': 249,
#                             'parentMemberId': 1,
#                             'terminated': 0,
#                             'vintage': None},
#                            {'classificationCode': None,
#                             'classificationTypeCode': None,
#                             'geoLevel': None,
#                             'memberId': 6,
#                             'memberNameFr': "Taux d'incarcération pour 10 000 "
#                                             'jeunes',
#                             'memberUomCode': 257,
#                             'parentMemberId': None,
#                             'terminated': 0,
#                             'vintage': None},
#                            {'classificationCode': None,
#                             'classificationTypeCode': None,
#                             'geoLevel': None,
#                             'memberId': 7,
#                             'memberNameFr': 'Compte total de la surveillance '
#                                             'communautaire',
#                             'memberUomCode': 249,
#                             'parentMemberId': None,
#                             'terminated': 0,
#                             'vintage': None},
#                            {'classificationCode': None,
#                             'classificationTypeCode': None,
#                             'geoLevel': None,
#                             'memberId': 8,
#                             'memberNameFr': 'Probation, surveillance '
#                                             'communautaire',
#                             'memberUomCode': 249,
#                             'parentMemberId': 7,
#                             'terminated': 0,
#                             'vintage': None},
#                            {'classificationCode': None,
#                             'classificationTypeCode': None,
#                             'geoLevel': None,
#                             'memberId': 9,
#                             'memberNameFr': "Partie communautaire d'une "
#                                             'ordonnance de garde, surveillance '
#                                             'communautaire',
#                             'memberUomCode': 249,
#                             'parentMemberId': 7,
#                             'terminated': 0,
#                             'vintage': None},
#                            {'classificationCode': None,
#                             'classificationTypeCode': None,
#                             'geoLevel': None,
#                             'memberId': 10,
#                             'memberNameFr': 'Ordonnance différée de placement '
#                                             'sous garde, surveillance '
#                                             'communautaire',
#                             'memberUomCode': 249,
#                             'parentMemberId': 7,
#                             'terminated': 0,
#                             'vintage': None},
#                            {'classificationCode': None,
#                             'classificationTypeCode': None,
#                             'geoLevel': None,
#                             'memberId': 11,
#                             'memberNameFr': "Programme d'assistance et de "
#                                             'surveillance intensive, '
#                                             'surveillance communautaire',
#                             'memberUomCode': 249,
#                             'parentMemberId': 7,
#                             'terminated': 0,
#                             'vintage': None},
#                            {'classificationCode': None,
#                             'classificationTypeCode': None,
#                             'geoLevel': None,
#                             'memberId': 12,
#                             'memberNameFr': 'Taux de probation pour 10 000 '
#                                             'jeunes',
#                             'memberUomCode': 257,
#                             'parentMemberId': None,
#                             'terminated': 0,
#                             'vintage': None}]}],
#  'footnote': [{'footnoteId': 1,
#                'footnotesFr': 'Rapport sur les indicateurs clés des services '
#                               'correctionnels pour les jeunes, Centre canadien '
#                               'de la statistique juridique et de la sécurité '
#                               'des collectivités (CCSJSC), Statistique Canada. '
#                               'Exercice (1er avril au 31 mars). Les chiffres '
#                               'ayant été arrondis, leur somme peut ne pas '
#                               'correspondre aux totaux indiqués. Ces données '
#                               'sont des données administratives. Même si dans '
#                               'le Rapport sur les indicateurs clés des '
#                               'services correctionnels on tente de normaliser '
#                               'la façon dont les données sont déclarées, dans '
#                               'certains cas, des limites attribuables à des '
#                               'différences dans les activités des secteurs de '
#                               "compétence peuvent restreindre l'application "
#                               "uniforme des définitions. C'est la raison pour "
#                               'laquelle il faut faire preuve de prudence '
#                               "lorsque l'on effectue des comparaisons entre "
#                               'les secteurs de compétence. La Loi sur le '
#                               'système de justice pénale pour les adolescents '
#                               'est entrée en vigueur le 1er avril 2003. Par '
#                               'conséquent, les comparaisons entre les secteurs '
#                               "de compétence et à l'intérieur de ceux-ci "
#                               'doivent être effectuées avec prudence pour les '
#                               'années qui précèdent et qui suivent 2003-2004.',
#                'link': {'dimensionPositionId': 0,
#                         'footnoteId': 1,
#                         'memberId': 0}},
#               {'footnoteId': 2,
#                'footnotesFr': 'Les données représentent le total pour '
#                               "l'ensemble des secteurs de compétence "
#                               'déclarants. Les données pour certaines années '
#                               'peuvent être incomplètes en raison de données '
#                               'manquantes pour un ou plusieurs secteurs de '
#                               'compétence. Les comparaisons entre les années à '
#                               "l'échelon national doivent être effectuées avec "
#                               'prudence. Sauf indication contraire, les '
#                               'comptes de la détention avant le procès et des '
#                               'autres types de détention temporaire, de la '
#                               'détention après condamnation et de la '
#                               'surveillance communautaire peuvent comprendre '
#                               'la détention provisoire ordonnée par le '
#                               'directeur provincial dans certains secteurs de '
#                               'compétence. Antérieurement à 2003/2004 en '
#                               'Ontario, des estimations sont utilisées pour '
#                               'les 12 à 15 ans en détention provisoire et en '
#                               'détention temporaire afin de calculer les taux '
#                               "nationaux d'incarcération des adolescents. Ces "
#                               "estimations ne sont pas utilisées à l'échelle "
#                               'provinciale.',
#                'link': {'dimensionPositionId': 1,
#                         'footnoteId': 2,
#                         'memberId': 15}},
#               {'footnoteId': 25,
#                'footnotesFr': 'Pour Terre-Neuve-et-Labrador, les comptes de « '
#                               "Programme d'assistance et de surveillance "
#                               'intensive, surveillance communautaire » ne sont '
#                               'pas disponibles pour 2003-2004 et à partir de '
#                               '2012-2013. En 2017-2018, les chiffres de '
#                               'Terre-Neuve-et-Labrador relatifs au placement '
#                               'sous garde et à la surveillance au sein de la '
#                               'collectivité des jeunes ont été compilés à '
#                               'partir d’une nouvelle source, soit l’Enquête '
#                               'sur les services correctionnels canadiens. '
#                               'Certaines variations par rapport aux années '
#                               'précédentes peuvent être attribuables à ce '
#                               'changement. En 2023-2024, les données sur le '
#                               'placement sous garde des jeunes de '
#                               'Terre-Neuve-et-Labrador ne sont pas '
#                               'disponibles.',
#                'link': {'dimensionPositionId': 1,
#                         'footnoteId': 25,
#                         'memberId': 1}},
#               {'footnoteId': 3,
#                'footnotesFr': "À l'Île-du-Prince-Édouard, les comptes de la "
#                               'probation comprennent les cas de sanctions '
#                               'extrajudiciaires dans les données historiques. '
#                               'Les données sur la surveillance communautaire '
#                               'sont indisponibles pour 2005-2006. Les comptes '
#                               "d'ordonnance différée de placement sous garde "
#                               'sont indisponibles pour 2003-2004 et de '
#                               '2006-2007 à 2008-2009. Les comptes de programme '
#                               "d'assistance et surveillance intensive pour "
#                               'toutes les années sont indisponibles. En '
#                               '2023-2024, les comptes de la surveillance '
#                               'communautaire ont été révisés pour 2022-2023. '
#                               'En 2023-2024, les comptes quotidiens moyens '
#                               'pour l’Île-du-Prince-Édouard  ont commencé à '
#                               "être compilés à partir d'une nouvelle source, "
#                               "soit l'Enquête sur les services correctionnels "
#                               'canadiens. Certaines variations par rapport aux '
#                               'années précédentes peuvent être attribuables à '
#                               'cette transition et aux différences de '
#                               'méthodologie entre les sources. Il faut faire '
#                               "preuve de prudence lorsqu'on effectue des "
#                               'comparaisons avec les années précédentes.',
#                'link': {'dimensionPositionId': 1,
#                         'footnoteId': 3,
#                         'memberId': 2}},
#               {'footnoteId': 4,
#                'footnotesFr': 'Avant 2006-2007, en Nouvelle-Écosse, les '
#                               'comptes de la probation comprennent les '
#                               'ordonnances différées de placement sous garde '
#                               'et de surveillance. Avant octobre 2004, la '
#                               'détention avant le procès et les autres types '
#                               'de détention temporaire comprenaient la '
#                               'détention provisoire ordonnée par le directeur '
#                               'provincial. Tous les comptes des contrevenants '
#                               'sous surveillance communautaire sont '
#                               'indisponibles à partir de 2006-2007 à '
#                               '2022-2023. En 2023-2024, les comptes quotidiens '
#                               'moyens pour la Nouvelle-Écosse ont commencé à '
#                               "être compilés à partir d'une nouvelle source, "
#                               "soit l'Enquête sur les services correctionnels "
#                               'canadiens. Certaines variations par rapport aux '
#                               'années précédentes peuvent être attribuables à '
#                               'cette transition et aux différences de '
#                               'méthodologie entre les sources. Il faut faire '
#                               "preuve de prudence lorsqu'on effectue des "
#                               'comparaisons avec les années précédentes.',
#                'link': {'dimensionPositionId': 1,
#                         'footnoteId': 4,
#                         'memberId': 3}},
#               {'footnoteId': 5,
#                'footnotesFr': 'Les données du Nouveau-Brunswick proviennent '
#                               "d'un nouveau système depuis 2000-2001. Il est "
#                               'recommandé de faire preuve de prudence lorsque '
#                               "l'on compare les données à partir de 2000-2001 "
#                               'avec celles des années antérieures. Au '
#                               'Nouveau-Brunswick, les comptes des '
#                               'contrevenants sous surveillance communautaire '
#                               'sont indisponibles dès 2000-2001. Les données '
#                               'sur la probation pour 1999-2000 sont des '
#                               'estimations. À partir de 2000-2001 les comptes '
#                               "des personnes détenus en vertu d'un statut "
#                               'mixte (détention provisoire et détention après '
#                               'condamnation) sont inclus dans les comptes de '
#                               'la détention provisoire.',
#                'link': {'dimensionPositionId': 1,
#                         'footnoteId': 5,
#                         'memberId': 4}},
#               {'footnoteId': 23,
#                'footnotesFr': 'Au Québec, les données sont indisponibles à '
#                               'partir de 2011-2012. Les comptes quotidiens '
#                               'moyens du Québec sont des estimations fondées '
#                               "sur le nombre total de jours durant l'année "
#                               'divisé par 365. Le compte des jeunes purgeant '
#                               "la partie communautaire d'une ordonnance de "
#                               'garde est indisponible.',
#                'link': {'dimensionPositionId': 1,
#                         'footnoteId': 23,
#                         'memberId': 5}},
#               {'footnoteId': 6,
#                'footnotesFr': 'En Ontario, les données sur la détention avant '
#                               'le procès et les autres types de détention '
#                               'temporaire pour les jeunes de 12 à 15\xa0ans ne '
#                               'sont pas disponibles avant 2003-2004. Ainsi, '
#                               "les taux d'incarcération des jeunes ne sont pas "
#                               'disponibles avant 2003-2004. Depuis 2005-2006, '
#                               'les données sur les jeunes de 12 à 17\xa0ans '
#                               "sont recueillies dans un seul groupe d'âge. Les "
#                               'comptes des jeunes de 12 à 15\xa0ans sous garde '
#                               'en milieu fermé après condamnation et sous '
#                               'garde en milieu ouvert après condamnation sont '
#                               'des estimations pour 2002-2003 et 2003-2004. '
#                               'Les comptes de la partie communautaire des '
#                               'ordonnances de garde pour les jeunes de 12 à 15 '
#                               'ans sont des estimations pour 2003-2004. Les '
#                               "comptes de programme d'assistance et de "
#                               'surveillance intensive, surveillance '
#                               'communautaire sont indisponibles pour 2003-2004 '
#                               'et 2004-2005.',
#                'link': {'dimensionPositionId': 1,
#                         'footnoteId': 6,
#                         'memberId': 6}},
#               {'footnoteId': 7,
#                'footnotesFr': 'Au Manitoba, certaines personnes détenues par '
#                               'la police sont incluses dans le compte de la '
#                               'détention provisoire et les autres types de '
#                               'détention temporaire. Pour 2004-2005, les '
#                               'comptes moyens sont estimés. Le compte pour le '
#                               "programme d'assistance et de surveillance "
#                               'intensive est indisponible.',
#                'link': {'dimensionPositionId': 1,
#                         'footnoteId': 7,
#                         'memberId': 7}},
#               {'footnoteId': 24,
#                'footnotesFr': 'En Saskatchewan, les comptes de la détention '
#                               'avant le procès et des autres types de '
#                               'détention temporaire comprennent les jeunes en '
#                               "détention provisoire sous l'autorité du "
#                               'directeur provincial. Le compte des jeunes sous '
#                               "ordonnance de suivre un programme d'assistance "
#                               'et de surveillance intensives est indisponible. '
#                               'En 2017-2018, les chiffres de Saskatchewan '
#                               'relatifs au placement sous garde et à la '
#                               'surveillance au sein de la collectivité des '
#                               'jeunes ont été compilés à partir d’une nouvelle '
#                               'source, soit l’Enquête sur les services '
#                               'correctionnels canadiens. Certaines variations '
#                               'par rapport aux années précédentes peuvent être '
#                               'attribuables à ce changement.',
#                'link': {'dimensionPositionId': 1,
#                         'footnoteId': 24,
#                         'memberId': 8}},
#               {'footnoteId': 8,
#                'footnotesFr': "Les données de l'Alberta sont indisponibles "
#                               'pour 2013-2014 et les comptes des contrevenants '
#                               'sous surveillance communautaire sont '
#                               'indisponibles pour 2014-2015. Les données de '
#                               "l'Alberta pour 2012-2013 sont fondées sur dix "
#                               'mois de données réelles en raison de '
#                               "l'indisponibilité des renseignements en février "
#                               'et mars 2013. Il faut faire preuve de prudence '
#                               "lorsque l'on effectue des comparaisons de "
#                               "2012-2013 à d'autres années. En Alberta, les "
#                               'comptes de la détention avant le procès et des '
#                               'autres types de détention temporaire pour '
#                               '2003-2004 sont fondés sur les comptes mensuels '
#                               "moyens. En 2019-2020, l'Alberta a mis en œuvre "
#                               'un changement de déclaration pour inclure les '
#                               'jeunes placés sous garde dans les foyers '
#                               "collectifs, selon la définition de l'enquête. "
#                               "Il faut faire preuve de prudence lorsqu'on "
#                               'effectue des comparaisons avec les années '
#                               'précédentes. En 2023-2024, les comptes '
#                               'quotidiens moyens pour l’Alberta ont commencé à '
#                               "être compilés à partir d'une nouvelle source, "
#                               "soit l'Enquête sur les services correctionnels "
#                               'canadiens. Certaines variations par rapport aux '
#                               'années précédentes peuvent être attribuables à '
#                               'cette transition et aux différences de '
#                               'méthodologie entre les sources. Il faut faire '
#                               "preuve de prudence lorsqu'on effectue des "
#                               'comparaisons avec les années précédentes.',
#                'link': {'dimensionPositionId': 1,
#                         'footnoteId': 8,
#                         'memberId': 9}},
#               {'footnoteId': 9,
#                'footnotesFr': 'En raison de changements apportés aux systèmes '
#                               'et aux pratiques de déclaration en 2000-2001 et '
#                               'en 2006-2007, il est recommandé de faire preuve '
#                               "de prudence lorsque l'on effectue des "
#                               'comparaisons pour la Colombie-Britannique. '
#                               'Avant 2003-2004, les comptes de la détention '
#                               'avant le procès et des autres types de '
#                               'détention temporaire ne comprenaient que les '
#                               'jeunes placés sous garde ordonnée par le '
#                               'tribunal avant le procès. Les données de la '
#                               'détention avant le procès et des autres types '
#                               'de détention temporaire pour 2003-2004 '
#                               'comprennent également un petit nombre de jeunes '
#                               'en détention avant-procès, par exemple les '
#                               'détentions par la police avant comparution. Les '
#                               'chiffres sur le placement sous garde des jeunes '
#                               'de la Colombie-Britannique, à partir de '
#                               '2017-2018, ainsi que ceux pour les services '
#                               'communautaires, à partir de 2018-2019, ont été '
#                               "compilés à partir d'une nouvelle source, soit "
#                               "l'Enquête sur les services correctionnels "
#                               'canadiens. Certaines variations par rapport aux '
#                               'années précédentes peuvent être attribuables à '
#                               'cette transition et aux différences de '
#                               'méthodologie entre les sources. Dans le cas des '
#                               'chiffres sur les services communautaires, plus '
#                               'particulièrement, ils sont maintenant fondés '
#                               "sur la date d'entrée en vigueur et la date "
#                               "d'expiration des ordonnances, tandis que "
#                               'précédemment, ils étaient fondés sur la '
#                               'surveillance de jeunes dans un bureau de '
#                               'probation, et ils excluent les cas où le '
#                               'dossier a été transféré du système de justice '
#                               'pour les jeunes à un bureau de probation pour '
#                               'adultes. Il faut faire preuve de prudence '
#                               "lorsqu'on effectue des comparaisons par rapport "
#                               'aux années précédentes. En 2021-2022, les '
#                               'méthodes permettant d’identifier les jeunes en '
#                               'probation à la fin du mois ont été mises à '
#                               'jour. Il faut donc faire preuve de prudence '
#                               'lorsqu’on effectue des comparaisons avec les '
#                               'années précédentes.',
#                'link': {'dimensionPositionId': 1,
#                         'footnoteId': 9,
#                         'memberId': 10}},
#               {'footnoteId': 10,
#                'footnotesFr': 'Au Yukon, les données sont indisponibles pour '
#                               "la partie communautaire d'une ordonnance de "
#                               'garde, les ordonnances différées de placement '
#                               'sous garde et de surveillance, et le programme '
#                               "d'assistance et de surveillance intensives "
#                               'avant 2003-2004. En 2021-2022, les chiffres sur '
#                               'le placement sous garde des jeunes pour la '
#                               'période allant de 2017-2018 à 2020-2021 ont été '
#                               'révisés pour le Yukon. Les totaux provinciaux '
#                               'et territoriaux ont donc été révisés et '
#                               'pourraient ne pas correspondre aux chiffres '
#                               'déjà publiés. En 2022-2023, les libérations '
#                               'conditionnelles avec une condition de rapport à '
#                               'faire à un agent de probation au Yukon sont '
#                               'maintenant considérées comme des « probation '
#                               'sous surveillance ».',
#                'link': {'dimensionPositionId': 1,
#                         'footnoteId': 10,
#                         'memberId': 11}},
#               {'footnoteId': 11,
#                'footnotesFr': 'En raison de la création du Nunavut à partir '
#                               'des Territoires du Nord-Ouest, les données '
#                               'recueillies avant 1999-2000 ne peuvent être '
#                               'comparées avec celles recueillies après cette '
#                               'date.\xa0Les données sur la surveillance '
#                               'communautaire sont indisponibles avant '
#                               '2008-2009.',
#                'link': {'dimensionPositionId': 1,
#                         'footnoteId': 11,
#                         'memberId': 12}},
#               {'footnoteId': 11,
#                'footnotesFr': 'En raison de la création du Nunavut à partir '
#                               'des Territoires du Nord-Ouest, les données '
#                               'recueillies avant 1999-2000 ne peuvent être '
#                               'comparées avec celles recueillies après cette '
#                               'date.\xa0Les données sur la surveillance '
#                               'communautaire sont indisponibles avant '
#                               '2008-2009.',
#                'link': {'dimensionPositionId': 1,
#                         'footnoteId': 11,
#                         'memberId': 13}},
#               {'footnoteId': 12,
#                'footnotesFr': 'Au Nunavut, les comptes de la probation sont '
#                               "fondés sur le nombre d'ordonnances de probation "
#                               'rendues par le tribunal, et non sur le nombre '
#                               'de jeunes en probation. En 2010-2011, le '
#                               'Nunavut a adopté un nouveau système de gestion '
#                               'de dossiers et a entrepris un examen de la '
#                               'qualité des données. Par conséquent, les '
#                               'données pour la période allant de 2001-2002 à '
#                               '2009-2010 ont été révisées et les données '
#                               'antérieures à 2001-2002 ont été supprimées. Les '
#                               'données sur les ordonnances différées de '
#                               'placement sous garde et de surveillance, et '
#                               "programme d'assistance et de surveillance "
#                               'intensives pour toutes les années sont '
#                               'indisponibles. En 2019-2020, les données de '
#                               'probation du Nunavut pour les jeunes ne sont '
#                               'pas disponibles ; par conséquent, le nombre '
#                               'total de jeunes sous surveillance dans la '
#                               "collectivité n'est pas disponible.",
#                'link': {'dimensionPositionId': 1,
#                         'footnoteId': 12,
#                         'memberId': 14}},
#               {'footnoteId': 13,
#                'footnotesFr': 'Le compte réel total des détenus représente la '
#                               'somme des comptes des jeunes placés en '
#                               'détention après condamnation, en détention '
#                               'avant le procès, en détention provisoire sous '
#                               "l'autorité du directeur provincial et dans "
#                               "d'autres types de détention temporaire au "
#                               'moment du dénombrement.',
#                'link': {'dimensionPositionId': 2,
#                         'footnoteId': 13,
#                         'memberId': 1}},
#               {'footnoteId': 14,
#                'footnotesFr': 'La garde en milieu fermé après condamnation '
#                               'comprend les jeunes qui purgent une peine en '
#                               'milieu fermé, ainsi que les jeunes qui ont été '
#                               'condamnés relativement à une accusation et qui '
#                               "attendent l'issue des audiences du tribunal "
#                               'concernant une autre accusation, sauf '
#                               'indication contraire. Cette catégorie comprend '
#                               'aussi les jeunes qui ont terminé la partie '
#                               'passée sous garde de leur peine et qui ont été '
#                               'de nouveau placés sous garde en milieu fermé à '
#                               "la suite d'un manquement aux conditions. Un "
#                               'établissement est considéré comme un milieu '
#                               'fermé lorsque les jeunes sont retenus sous '
#                               'garde au moyen de dispositifs de sécurité, ce '
#                               'qui inclut ceux qui sont dotés de fonctions '
#                               "permettant d'assurer la sécurité périmétrique "
#                               "complète de l'établissement et ceux qui "
#                               'permettent la surveillance continue des jeunes. '
#                               'La mesure dans laquelle les établissements sont '
#                               "des milieux fermés varie d'un secteur de "
#                               "compétence à l'autre.",
#                'link': {'dimensionPositionId': 2,
#                         'footnoteId': 14,
#                         'memberId': 3}},
#               {'footnoteId': 15,
#                'footnotesFr': 'La garde en milieu ouvert après condamnation '
#                               'comprend les jeunes qui purgent une peine en '
#                               'milieu ouvert, ainsi que les jeunes qui ont été '
#                               'condamnés relativement à une accusation et qui '
#                               "attendent l'issue des audiences du tribunal "
#                               'concernant une autre accusation, sauf '
#                               'indication contraire. Cette catégorie comprend '
#                               'aussi les jeunes qui ont terminé une peine de '
#                               'garde et qui ont été de nouveau placés sous '
#                               "garde en milieu ouvert à la suite d'un "
#                               'manquement aux conditions. Les établissements '
#                               'de garde en milieu ouvert comprennent les '
#                               'centres résidentiels communautaires, les foyers '
#                               "collectifs, les établissements d'aide à "
#                               "l'enfance, ainsi que les camps forestiers et de "
#                               'pleine nature, et tous les lieux et '
#                               'établissements semblables. Un établissement est '
#                               "considéré comme un milieu ouvert lorsqu'on y "
#                               'fait un usage minimal de dispositifs de '
#                               'sécurité ou de sécurité périphérique. La mesure '
#                               'dans laquelle les établissements sont des '
#                               "milieux ouverts varie d'un secteur de "
#                               "compétence à l'autre. Au Québec, la garde en "
#                               'milieu ouvert comprend les peines discontinues, '
#                               "même si la loi permet qu'une peine discontinue "
#                               'soit purgée en milieu fermé (voir le paragraphe '
#                               '47(2) de la Loi sur le système de justice '
#                               'pénale pour les adolescents).',
#                'link': {'dimensionPositionId': 2,
#                         'footnoteId': 15,
#                         'memberId': 4}},
#               {'footnoteId': 16,
#                'footnotesFr': 'La détention avant le procès ne comprend que '
#                               'les jeunes détenus qui attendent de se '
#                               'présenter de nouveau en cour et ceux qui ne '
#                               'purgent pas actuellement un type quelconque de '
#                               'peine, sauf indication contraire.',
#                'link': {'dimensionPositionId': 2,
#                         'footnoteId': 16,
#                         'memberId': 5}},
#               {'footnoteId': 17,
#                'footnotesFr': "Les taux d'incarcération sont fondés sur le "
#                               'compte réel total des jeunes, ainsi que sur les '
#                               'estimations actuelles de la population pour les '
#                               'jeunes de 12 à 17 ans fournies par le Centre de '
#                               'démographie, Statistique Canada (accessibles au '
#                               'moment de la diffusion des données). Il '
#                               'convient de noter que certains jeunes placés '
#                               "sous garde peuvent avoir 20 ans s'ils avaient "
#                               "moins de 18\xa0ans au moment de l'infraction, "
#                               "mais qu'ils ont atteint la majorité depuis.",
#                'link': {'dimensionPositionId': 2,
#                         'footnoteId': 17,
#                         'memberId': 6}},
#               {'footnoteId': 18,
#                'footnotesFr': 'La probation est un type de sanction orientée '
#                               'sur la collectivité où le jeune contrevenant '
#                               "est placé sous la surveillance d'un agent de "
#                               "probation ou d'une autre personne désignée. La "
#                               'probation sous surveillance comprend les jeunes '
#                               "qui doivent, comme condition d'une ordonnance "
#                               'de probation, « se présenter au directeur '
#                               'provincial ou à la personne désignée par le '
#                               'tribunal pour adolescents et se soumettre à sa '
#                               'surveillance ».',
#                'link': {'dimensionPositionId': 2,
#                         'footnoteId': 18,
#                         'memberId': 8}},
#               {'footnoteId': 19,
#                'footnotesFr': 'Sous le régime de la Loi sur le système de '
#                               'justice pénale pour les adolescents introduit '
#                               'en 2003-2004, tous les jeunes condamnés à un '
#                               'placement sous garde doivent passer une période '
#                               'sous surveillance dans la collectivité après '
#                               'avoir terminé la partie passée sous garde de '
#                               "leur peine. La partie communautaire d'une "
#                               'ordonnance de garde représente la partie de '
#                               "l'ordonnance de placement et de surveillance "
#                               'qui doit être purgée dans la collectivité.',
#                'link': {'dimensionPositionId': 2,
#                         'footnoteId': 19,
#                         'memberId': 9}},
#               {'footnoteId': 20,
#                'footnotesFr': 'Sous le régime de la Loi sur le système de '
#                               'justice pénale pour les adolescents introduit '
#                               'en 2003-2004, une ordonnance différée de '
#                               'placement sous garde et de surveillance permet '
#                               'à un jeune qui autrement serait condamné à une '
#                               'peine de garde de purger sa sentence dans la '
#                               "collectivité sous réserve d'un certain nombre "
#                               'de conditions. Un jeune qui viole les '
#                               'conditions de son ordonnance peut être placé '
#                               'sous garde.',
#                'link': {'dimensionPositionId': 2,
#                         'footnoteId': 20,
#                         'memberId': 10}},
#               {'footnoteId': 21,
#                'footnotesFr': 'Sous le régime de la Loi sur le système de '
#                               'justice pénale pour les adolescents (LSJPA) '
#                               "introduit en 2003-2004, l'ordonnance de suivre "
#                               "un programme d'assistance et de surveillance "
#                               'intensives est une solution de rechange à '
#                               "l'incarcération. À l'instar de la probation, "
#                               "l'ordonnance de suivre un programme "
#                               "d'assistance et de surveillance intensives est "
#                               "purgée dans la collectivité sous réserve d'un "
#                               'certain nombre de conditions, mais elle prévoit '
#                               'une surveillance et un soutien plus étroits '
#                               "afin d'aider le jeune à changer son "
#                               "comportement. Il s'agit d'une peine facultative "
#                               'en vertu de la LSJPA, ce qui signifie que les '
#                               'secteurs de compétence ne sont pas tenus de '
#                               'mettre en œuvre cette option.',
#                'link': {'dimensionPositionId': 2,
#                         'footnoteId': 21,
#                         'memberId': 11}},
#               {'footnoteId': 22,
#                'footnotesFr': 'Les taux de probation pour les jeunes sont '
#                               'calculés pour chaque secteur de compétence à '
#                               "l'aide des estimations actuelles de la "
#                               'population pour les jeunes de 12 à 17\xa0ans '
#                               'fournies par le Centre de démographie, '
#                               'Statistique Canada (accessibles au moment de la '
#                               'diffusion des données).',
#                'link': {'dimensionPositionId': 2,
#                         'footnoteId': 22,
#                         'memberId': 12}}],
#  'frequencyCode': 12,
#  'issueDate': '2021-04-13',
#  'nbDatapointsCube': 4476,
#  'nbSeriesCube': 174,
#  'productId': '35100003',
#  'releaseTime': '2025-09-23T08:30',
#  'responseStatusCode': 0,
#  'subjectCode': ['4211', '350102'],
#  'surveyCode': ['3313']}
